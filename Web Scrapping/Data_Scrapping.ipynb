# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Production_car_speed_record'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-appearance-disabled vector-feature-appearance-pinned-clientpref-0 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Production car speed record - Wikipedia</title>
# ...

# %%
table = soup.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable" style="font-size:100%;">
# <tbody><tr>
# <th>Year
# </th>
# <th>Make and model
# </th>
# <th>Top speed
# </th>
# <th>Engine
# </th>
# <th>Number built
# </th>
# <th>Comment
# </th></tr>
# <tr>
# <td>1951
# </td>
# <td><a href="/wiki/Pegaso_Z-102" title="Pegaso Z-102">Pegaso Z-102</a>
# </td>
# <td>245 km/h (152 mph)
# </td>
# <td>3,178 cc (193.9 cu in) V8 268 kW (365 PS; 360 bhp)
# </td>
# <td>84
# </td>
# <td>360 hp turbocharged variant. Tested by Belgian Automobile club, at Belgium's Jabbeke highway, but the results are not officially recognized worldwide. Classic Car commented that the Z-102 tested was a proto-type.<sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup>
# </td></tr>
# <tr>
# <td rowspan="2">1959
# </td>
# <td rowspan="2"><a href="/wiki/Maserati_5000_GT" title="Maserati 5000 GT">Maserati 5000 GT</a>
# </td>
# <td rowspan="2">277 km/h (172.4 mph)
# </td>
# ...

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th>Year
#  </th>,
#  <th>Make and model
#  </th>,
#  <th>Top speed
#  </th>,
#  <th>Engine
#  </th>,
#  <th>Number built
#  </th>,
#  <th>Comment
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

print(world_table_titles)
# Out:
# ['Year', 'Make and model', 'Top speed', 'Engine', 'Number built', 'Comment']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Year, Make and model, Top speed, Engine, Number built, Comment]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
column_data
# Out:
# [<tr>
#  <th>Year
#  </th>
#  <th>Make and model
#  </th>
#  <th>Top speed
#  </th>
#  <th>Engine
#  </th>
#  <th>Number built
#  </th>
#  <th>Comment
#  </th></tr>,
#  <tr>
#  <td>1951
#  </td>
#  <td><a href="/wiki/Pegaso_Z-102" title="Pegaso Z-102">Pegaso Z-102</a>
#  </td>
#  <td>245 km/h (152 mph)
#  </td>
#  <td>3,178 cc (193.9 cu in) V8 268 kW (365 PS; 360 bhp)
#  </td>
#  <td>84
#  </td>
#  <td>360 hp turbocharged variant. Tested by Belgian Automobile club, at Belgium's Jabbeke highway, but the results are not officially recognized worldwide. Classic Car commented that the Z-102 tested was a proto-type.<sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup>
#  </td></tr>,
#  <tr>
#  <td rowspan="2">1959
#  </td>
#  <td rowspan="2"><a href="/wiki/Maserati_5000_GT" title="Maserati 5000 GT">Maserati 5000 GT</a>
#  </td>
#  <td rowspan="2">277 km/h (172.4 mph)
#  </td>
#  <td>4,935 cc (301.2 cu in) V8 254 kW (345 PS; 340 bhp)
#  </td>
#  <td>2
#  </td>
# ...

# %%
#for row in column_data[1:]:
#  row_data = row.find_all('td')
#  individual_row_data = [data.text.strip() for data in row_data]
#  length = len(df)
#  df.loc[length] = individual_row_data

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    # Check if the number of elements in individual_row_data matches the number of columns in df
    if len(individual_row_data) == len(df.columns):
        length = len(df)
        df.loc[length] = individual_row_data
    else:
        print("Number of elements in individual_row_data doesn't match the number of columns in df")
# Out:
# Number of elements in individual_row_data doesn't match the number of columns in df

# %%
df
# Out:
#     Year                   Make and model                         Top speed  \
# 0   1951                     Pegaso Z-102                245 km/h (152 mph)
# 1   1959                 Maserati 5000 GT              277 km/h (172.4 mph)
# 2   1951                     Pegaso Z-102                245 km/h (152 mph)
# 3   1959                 Maserati 5000 GT              277 km/h (172.4 mph)
# 4   1951                     Pegaso Z-102                245 km/h (152 mph)
# 5   1959                 Maserati 5000 GT              277 km/h (172.4 mph)
# 6   1951                     Pegaso Z-102                245 km/h (152 mph)
# 7   1959                 Maserati 5000 GT              277 km/h (172.4 mph)
# 8   1985      Lamborghini Countach 5000QV            298 km/h (185 mph)[36]
# 9   1990                        Vector W8  389 km/h (242 mph) for prototype
# 10  1992                     Jaguar XJ220        338.8 km/h (210.5 mph)[38]
# ...
